# %%
import warnings

import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm
import theano.tensor as tt
import pandas as pd
import csv

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# %config InlineBackend.figure_format = 'retina'
az.style.use("arviz-darkgrid")
print(f"Running on PyMC3 v{pm.__version__}")
print(f"Running on ArviZ v{az.__version__}")
# Out:
# Running on PyMC3 v3.11.0
# Running on ArviZ v0.11.0

# %%
df = pd.read_csv(r'alaskaPopulation.csv')
df
# Out:
#    Unnamed: 0  Unnamed: 1         Unnamed: 2   Unnamed: 3      Unnamed: 4  \
# 0      Alaska         NaN                NaN          NaN             NaN
# 1         NaN  Population  Population Change  Vote Margin  Education Rate
# 2        2000     632,716              4,370          NaN             NaN
# 3        2002     649,466              7,737      -155305             NaN
# 4        2004     667,146              7,493        -9349             NaN
# 5        2006     680,169              5,586          NaN             NaN
# 6        2008     697,828             11,010         3953             NaN
# 7        2010     722,262              8,349       -30794             NaN
# 8        2012     736,077              5,428          NaN             NaN
# 9        2014     736,989                573        -6014             NaN
# 10       2016     737,783             -1,866      -101949             NaN
# 11       2018     731,007             -3,048          NaN             NaN
# 12       2020         NaN                NaN       -45044             NaN
#
#       Unnamed: 5 Unnamed: 6       Unnamed: 7       Unnamed: 8 Unnamed: 9  \
# 0   Demographics        NaN              NaN              NaN        NaN
# 1          White      Black  Hispanic/Latino  American Indian       AAPI
# 2        463,075     27,425           27,892          108,430     33,786
# 3        472,059     28,357           31,483          111,314     37,736
# 4        482,786     29,482           34,703          113,773     41,105
# 5        490,232     30,599           36,579          115,421     43,917
# 6        499,690     31,530           38,426          117,974     48,634
# 7        527,690     34,168           39,249          139,782     50,945
# 8        538,838     36,808           44,934          144,833     56,922
# 9        537,212     37,705           49,801          146,969     59,161
# 10       532,652     39,039           52,480          147,852     62,661
# 11       525,888     39,017           52,842          148,042     63,455
# 12           NaN        NaN              NaN              NaN        NaN
#
#    Unnamed: 10 Unnamed: 11      Unnamed: 12
# 0          NaN         NaN              NaN
# 1        Other     Turnout  Eligible Voters
# 2          NaN         NaN              NaN
# 3          NaN         NaN              NaN
# 4          NaN         NaN              NaN
# 5          NaN         NaN              NaN
# 6          NaN         NaN              NaN
# 7          NaN         NaN              NaN
# 8          NaN         NaN              NaN
# 9          NaN         NaN              NaN
# 10         NaN         NaN              NaN
# 11         NaN         NaN              NaN
# 12         NaN         NaN              NaN

# %%
with pm.Model() as model:
    # Model definition
    pass
